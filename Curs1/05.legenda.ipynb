# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x1 = [1, 2, 3, 4]
y1 = [10, 20, 30, 40]

x2 = [10, 20, 30, 40]
y2 = [101, 102, 103, 104]

plt.plot(x1, y1)
plt.plot(x2, y2);

# %%
x1 = [1, 2, 3, 4]
y1 = [10, 20, 30, 40]

x2 = [10, 20, 30, 40]
y2 = [101, 102, 103, 104]

plt.plot(x1, y1)
plt.plot(x2, y2);
plt.legend(["Primul", "Al doilea"])

# %%
x1 = [1, 2, 3, 4]
y1 = [10, 20, 30, 40]

x2 = [10, 20, 30, 40]
y2 = [101, 102, 103, 104]

plt.plot(x1, y1)
plt.plot(x2, y2);
plt.legend(["Primul", "Al doilea"],loc= 'center')

# %%
x1 = [1, 2, 3, 4]
y1 = [10, 20, 30, 40]

x2 = [10, 20, 30, 40]
y2 = [101, 102, 103, 104]

plt.plot(x1, y1)
plt.plot(x2, y2);
plt.legend(["Primul", "Al doilea"],loc='best', bbox_to_anchor=(0.5, 0., 0.5, 0.5))
