# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.random.normal(0, 1, 30)
y = np.random.normal(0, 1, 30)

plt.scatter(x, y)

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)
plt.plot(x, y)

# %%
plt.plot([101, 202, 303, 404])

# %%
plt.plot([101, 202, 303, 404], [0, 1, 2, 3])

# %%
plt.scatter(x=[10, 20, 30], y=[101, 202, 303])

# %%
plt.scatter([10, 20, 30], [101, 202, 303])

# %%
x=[10, 20, 30]
y=[101, 202, 303]

# %%
print(x)
# Out:
# [10, 20, 30]

# %%
plt.hist(x);

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(x=x, height=y);

# %%
plt.barh(x, width=y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(x);

# %%
plt.pie([1, 2, 1]);

# %%
plt.pie([1, 2, 1, 4]);

# %%
plt.pie([1, 2, 1, 4], labels=["a", "b", "c", "d"]);

# %%
plt.pie([1, 2, 1, 4, 3], labels=["a", "b", "c", "d", "e"]);

# %%
plt.title("Pie chart")
plt.pie([1, 2, 1, 4, 3], labels=["a", "b", "c", "d", "e"]);

# %%
plt.title("Pie chart")
plt.pie([1, 2, 1, 4, 3], labels=["a", "b", "c", "d", "e"], shadow=True);

# %%
plt.title("Pie chart")
plt.pie([1, 2, 1, 4, 3], labels=["a", "b", "c", "d", "e"], shadow=True, rotatelabels=True);

# %%
plt.title("Pie chart")
plt.pie([1, 2, 1, 4, 3], labels=["Val a", "Val b", "Val c", "Val d", "Val e"], shadow=True, rotatelabels=True);

# %%
plt.title("Pie chart")
plt.pie([1, 2, 1, 4, 3], labels=["Val a", "Val b", "Val c", "Val d", "Val e"], colors=["black", "yellow", "red", "green", "#Fe4503"], shadow=True, rotatelabels=True);

# %%
plt.title("Pie chart")
plt.pie([1, 2, 1, 4, 3], labels=["Val a", "Val b", "Val c", "Val d", "Val e"], colors=["black", "yellow", "red", "green", "#Fe4503"], shadow=True, rotatelabels=True);
plt.savefig("03.Piechart.png");
