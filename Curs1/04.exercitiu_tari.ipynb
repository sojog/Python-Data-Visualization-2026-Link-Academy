# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('tari.csv')
df
# Out:
#    pozition        country  population
# 0         8     Bangladesh         170
# 1         6         Brazil         213
# 2         1          China        1411
# 3         2          India        1378
# 4         4      Indonesia         271
# 5        10         Mexico         126
# 6         7        Nigeria         211
# 7         5       Pakistan         225
# 8         9         Russia         146
# 9         3  United States         331

# %%
df["country"]
# Out:
# 0       Bangladesh
# 1           Brazil
# 2            China
# 3            India
# 4        Indonesia
# 5           Mexico
# 6          Nigeria
# 7         Pakistan
# 8           Russia
# 9    United States
# Name: country, dtype: object

# %%
df.country
# Out:
# 0       Bangladesh
# 1           Brazil
# 2            China
# 3            India
# 4        Indonesia
# 5           Mexico
# 6          Nigeria
# 7         Pakistan
# 8           Russia
# 9    United States
# Name: country, dtype: object

# %%
plt.pie(df.population);

# %%
plt.pie(df.population, labels=df.country);

# %%
plt.pie(df.population, labels=df.country, autopct="%1.2f%%");

# %%
plt.bar(df.country, df.population)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.xticks(rotation=90)
plt.bar(df.country, df.population);

# %%
plt.xticks(rotation=45)
plt.bar(df.country, df.population);
