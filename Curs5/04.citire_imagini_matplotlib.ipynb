# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import numpy as np

# %%
imagine_citita_numpy = plt.imread("Milan2007/09.Kaka.png")
type(imagine_citita_numpy)
# Out:
# numpy.ndarray

# %%
plt.imshow(imagine_citita_numpy)

# %%
fig, axes = plt.subplots(1, 4)

for ax in axes.flatten():
    ax.imshow(imagine_citita_numpy)

# %%
axes
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)
