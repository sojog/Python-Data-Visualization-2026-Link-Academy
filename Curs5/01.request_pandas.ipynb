# %%
import pandas as pd
import requests
import matplotlib.pylab as plt
import seaborn as sns

# %%
TYPE = "products" ##  TYPE = "recipes"

URL = f"https://dummyjson.com/{TYPE}?limit=0"

# %%
response = requests.get(URL)
response.json()
# Out:
# {'products': [{'id': 1,
#    'title': 'Essence Mascara Lash Princess',
#    'description': 'The Essence Mascara Lash Princess is a popular mascara known for its volumizing and lengthening effects. Achieve dramatic lashes with this long-lasting and cruelty-free formula.',
#    'category': 'beauty',
#    'price': 9.99,
#    'discountPercentage': 10.48,
#    'rating': 2.56,
#    'stock': 99,
#    'tags': ['beauty', 'mascara'],
#    'brand': 'Essence',
#    'sku': 'BEA-ESS-ESS-001',
#    'weight': 4,
#    'dimensions': {'width': 15.14, 'height': 13.08, 'depth': 22.99},
#    'warrantyInformation': '1 week warranty',
#    'shippingInformation': 'Ships in 3-5 business days',
#    'availabilityStatus': 'In Stock',
#    'reviews': [{'rating': 3,
#      'comment': 'Would not recommend!',
#      'date': '2025-04-30T09:41:02.053Z',
#      'reviewerName': 'Eleanor Collins',
#      'reviewerEmail': 'eleanor.collins@x.dummyjson.com'},
#     {'rating': 4,
#      'comment': 'Very satisfied!',
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['products', 'total', 'skip', 'limit'])

# %%
df = pd.DataFrame(response.json()[TYPE])
df
# Out:
#       id                          title  \
# 0      1  Essence Mascara Lash Princess
# 1      2  Eyeshadow Palette with Mirror
# 2      3                Powder Canister
# 3      4                   Red Lipstick
# 4      5                Red Nail Polish
# ..   ...                            ...
# 189  190  IWC Ingenieur Automatic Steel
# 190  191        Rolex Cellini Moonphase
# 191  192           Rolex Datejust Women
# 192  193           Watch Gold for Women
# 193  194            Women's Wrist Watch
#
#                                            description        category  \
# 0    The Essence Mascara Lash Princess is a popular...          beauty
# 1    The Eyeshadow Palette with Mirror offers a ver...          beauty
# 2    The Powder Canister is a finely milled setting...          beauty
# 3    The Red Lipstick is a classic and bold choice ...          beauty
# 4    The Red Nail Polish offers a rich and glossy r...          beauty
# ...

# %%
df.to_csv(f"{TYPE}.csv", index=False)
